# %% [markdown]
# # Experiment 1

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('housing_price.csv')

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# std        0.724212      1.010771    3398.841946     401.26706     37.328178
# min        0.000000      0.000000       0.000000       0.00000   1196.000000
# 25%        1.000000      1.000000     224.000000     102.00000   1940.000000
# 50%        2.000000      2.000000     521.000000     136.00000   1970.000000
# 75%        2.000000      2.000000     670.000000     188.00000   2000.000000
# max       12.000000     26.000000  433014.000000   44515.00000   2106.000000
#
#           Lattitude    Longtitude  Propertycount
# count  26881.000000  26881.000000   34854.000000
# mean     -37.810634    145.001851    7572.888306
# std        0.090279      0.120169    4428.090313
# min      -38.190430    144.423790      83.000000
# 25%      -37.862950    144.933500    4385.000000
# 50%      -37.807600    145.007800    6763.000000
# 75%      -37.754100    145.071900   10412.000000
# max      -37.390200    145.526350   21650.000000

# %%
print(df.shape,df.size,df.ndim)
# Out:
# (34857, 21) 731997 2

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.columns.size #number of columns
# Out:
# 21

# %%
df.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 5  Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# 6  Abbotsford         55a Park St      4    h  1600000.0     VB   Nelson
# 7  Abbotsford        16 Maugie St      4    h        NaN     SN   Nelson
# 8  Abbotsford        53 Turner St      2    h        NaN      S   Biggin
# 9  Abbotsford        99 Turner St      2    h        NaN      S  Collins
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 5  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 6  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 7  6/08/2016       2.5    3067.0  ...       2.0  2.0     400.0         220.0
# 8  6/08/2016       2.5    3067.0  ...       1.0  2.0     201.0           NaN
# 9  6/08/2016       2.5    3067.0  ...       2.0  1.0     202.0           NaN
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
# 5        NaN  Yarra City Council  -37.7969    144.9969  Northern Metropolitan
# 6     2014.0  Yarra City Council  -37.8072    144.9941  Northern Metropolitan
# 7     2006.0  Yarra City Council  -37.7965    144.9965  Northern Metropolitan
# 8     1900.0  Yarra City Council  -37.7995    144.9974  Northern Metropolitan
# 9     1900.0  Yarra City Council  -37.7996    144.9989  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
# 5        4019.0
# 6        4019.0
# 7        4019.0
# 8        4019.0
# 9        4019.0
#
# [10 rows x 21 columns]

# %%
df=df.replace(0,np.NaN) #replace 0 with NaN

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance            78
# Postcode             1
# Bedroom2          8234
# Bathroom          8272
# Car              10359
# Landsize         14247
# BuildingArea     21191
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.head(10)
# Out:
#        Suburb             Address  Rooms Type      Price Method  SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS   Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S   Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S   Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB   Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP   Biggin
# 5  Abbotsford    40 Federation La      3    h   850000.0     PI   Biggin
# 6  Abbotsford         55a Park St      4    h  1600000.0     VB   Nelson
# 7  Abbotsford        16 Maugie St      4    h        NaN     SN   Nelson
# 8  Abbotsford        53 Turner St      2    h        NaN      S   Biggin
# 9  Abbotsford        99 Turner St      2    h        NaN      S  Collins
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  NaN     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       NaN           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  NaN     134.0         150.0
# 5  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 6  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 7  6/08/2016       2.5    3067.0  ...       2.0  2.0     400.0         220.0
# 8  6/08/2016       2.5    3067.0  ...       1.0  2.0     201.0           NaN
# 9  6/08/2016       2.5    3067.0  ...       2.0  1.0     202.0           NaN
#
#    YearBuilt         CouncilArea Lattitude  Longtitude             Regionname  \
# 0        NaN  Yarra City Council  -37.8014    144.9958  Northern Metropolitan
# 1        NaN  Yarra City Council  -37.7996    144.9984  Northern Metropolitan
# 2     1900.0  Yarra City Council  -37.8079    144.9934  Northern Metropolitan
# 3        NaN  Yarra City Council  -37.8114    145.0116  Northern Metropolitan
# 4     1900.0  Yarra City Council  -37.8093    144.9944  Northern Metropolitan
# 5        NaN  Yarra City Council  -37.7969    144.9969  Northern Metropolitan
# 6     2014.0  Yarra City Council  -37.8072    144.9941  Northern Metropolitan
# 7     2006.0  Yarra City Council  -37.7965    144.9965  Northern Metropolitan
# 8     1900.0  Yarra City Council  -37.7995    144.9974  Northern Metropolitan
# 9     1900.0  Yarra City Council  -37.7996    144.9989  Northern Metropolitan
#
#   Propertycount
# 0        4019.0
# 1        4019.0
# 2        4019.0
# 3        4019.0
# 4        4019.0
# 5        4019.0
# 6        4019.0
# 7        4019.0
# 8        4019.0
# 9        4019.0
#
# [10 rows x 21 columns]

# %%
df=df.dropna(thresh=20)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price            2185
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            4
# Bathroom            0
# Car               630
# Landsize         2091
# BuildingArea     1255
# YearBuilt         284
# CouncilArea         0
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df=df.fillna(value=df.loc[:,df.columns].mean()) 
#filling mean values
# Out:
# C:\Users\VISHWA~1\AppData\Local\Temp/ipykernel_7388/2569079880.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df=df.fillna(value=df.loc[:,df.columns].mean())

# %%
df.isnull().sum() #council dtype is object
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.dtypes.value_counts()
# Out:
# float64    12
# object      8
# int64       1
# dtype: int64

# %%
print(df.shape,df.size,df.ndim)
# Out:
# (13772, 21) 289212 2

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#            Suburb           Address  Rooms Type         Price Method  SellerG  \
# 2      Abbotsford   25 Bloomburg St      2    h  1.035000e+06      S   Biggin
# 4      Abbotsford      5 Charles St      3    h  1.465000e+06     SP   Biggin
# 6      Abbotsford       55a Park St      4    h  1.600000e+06     VB   Nelson
# 7      Abbotsford      16 Maugie St      4    h  1.094868e+06     SN   Nelson
# 11     Abbotsford      124 Yarra St      3    h  1.876000e+06      S   Nelson
# ...           ...               ...    ...  ...           ...    ...      ...
# 34849     Wollert   35 Kingscote Wy      3    h  5.700000e+05     SP       RW
# 34850     Wollert  15 Rockgarden Wy      3    h  1.094868e+06     SP       LJ
# 34853  Yarraville     29A Murray St      2    h  8.880000e+05     SP  Sweeney
# 34854  Yarraville    147A Severn St      2    t  7.050000e+05      S      Jas
# 34856  Yarraville  3 Tarrengower St      2    h  1.020000e+06     PI       RW
#
#              Date  Distance  Postcode  Bedroom2  Bathroom       Car  Landsize  \
# 2       4/02/2016       2.5    3067.0       2.0       1.0  1.838381     156.0
# 4       4/03/2017       2.5    3067.0       3.0       2.0  1.838381     134.0
# 6       4/06/2016       2.5    3067.0       3.0       1.0  2.000000     120.0
# 7       6/08/2016       2.5    3067.0       3.0       2.0  2.000000     400.0
# 11      7/05/2016       2.5    3067.0       4.0       2.0  1.838381     245.0
# ...           ...       ...       ...       ...       ...       ...       ...
# 34849  24/02/2018      25.5    3750.0       3.0       2.0  2.000000     404.0
# 34850  24/02/2018      25.5    3750.0       3.0       2.0  2.000000     268.0
# 34853  24/02/2018       6.3    3013.0       2.0       2.0  1.000000      98.0
# 34854  24/02/2018       6.3    3013.0       2.0       1.0  2.000000     220.0
# 34856  24/02/2018       6.3    3013.0       2.0       1.0  1.838381     250.0
#
#        BuildingArea  YearBuilt               CouncilArea  Lattitude  \
# 2              79.0     1900.0        Yarra City Council  -37.80790
# 4             150.0     1900.0        Yarra City Council  -37.80930
# 6             142.0     2014.0        Yarra City Council  -37.80720
# 7             220.0     2006.0        Yarra City Council  -37.79650
# 11            210.0     1910.0        Yarra City Council  -37.80240
# ...             ...        ...                       ...        ...
# 34849         158.0     2012.0   Whittlesea City Council  -37.61031
# 34850         135.0     2016.0   Whittlesea City Council  -37.61094
# 34853         104.0     2018.0  Maribyrnong City Council  -37.81551
# 34854         120.0     2000.0  Maribyrnong City Council  -37.82286
# 34856         103.0     1930.0  Maribyrnong City Council  -37.81810
#
#        Longtitude             Regionname
# 2       144.99340  Northern Metropolitan
# 4       144.99440  Northern Metropolitan
# 6       144.99410  Northern Metropolitan
# 7       144.99650  Northern Metropolitan
# 11      144.99930  Northern Metropolitan
# ...           ...                    ...
# 34849   145.03393  Northern Metropolitan
# 34850   145.04281  Northern Metropolitan
# 34853   144.88826   Western Metropolitan
# 34854   144.87856   Western Metropolitan
# 34856   144.89351   Western Metropolitan
#
# [13772 rows x 20 columns]

# %%
y
# Out:
# 2        4019.0
# 4        4019.0
# 6        4019.0
# 7        4019.0
# 11       4019.0
#           ...
# 34849    2940.0
# 34850    2940.0
# 34853    6543.0
# 34854    6543.0
# 34856    6543.0
# Name: Propertycount, Length: 13772, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,train_size=0.8,test_size=0.2,random_state=42)
print("Train size :",(len(x_train)/len(x))*100)
print("Test size :",(len(x_test)/len(x))*100)
# Out:
# Train size : 79.99564333430148
# Test size : 20.00435666569852
